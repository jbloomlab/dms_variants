# %% [markdown]
# # Test computation of escape scores
# Test computation of "escape scores" by `CodonVariantTable.escape_scores`.
#
# First create miniature test variant table:

# %%
import tempfile

import pandas as pd

import dms_variants.codonvarianttable

geneseq = 'ATGGGC'

variant_counts = (
    pd.DataFrame.from_records([
        ('lib1', 'AA', '', 'pre', 10),
        ('lib1', 'AG', 'ATG1CAA', 'pre', 20),
        ('lib2', 'TT', 'ATG1ATC', 'pre', 30),
        ('lib2', 'TA', 'ATG1ATC GGC2GGG', 'pre', 40),
        ('lib1', 'AA', '', 'post', 1),
        ('lib1', 'AG', 'ATG1CAA', 'post', 30),
        ('lib2', 'TT', 'ATG1ATC', 'post', 15),
        ('lib2', 'TA', 'ATG1ATC GGC2GGG', 'post', 5),
        ('lib1', 'AA', '', 'post2', 20),
        ('lib1', 'AG', 'ATG1CAA', 'post2', 40),
        ],
        columns=['library', 'barcode', 'codon_substitutions', 'sample', 'count']
        )
    .assign(variant_call_support=1)
    )

with tempfile.NamedTemporaryFile('w') as f:
    variant_counts.to_csv(f, index=False)
    f.flush()
    variants = dms_variants.codonvarianttable.CodonVariantTable.from_variant_count_df(
                    variant_count_df_file=f.name,
                    geneseq=geneseq)
    
variants.variant_count_df
# Out:
#   library sample barcode  count  variant_call_support codon_substitutions  \
# 0    lib1    pre      AG     20                     1             ATG1CAA
# 1    lib1    pre      AA     10                     1
# 2    lib1   post      AG     30                     1             ATG1CAA
# 3    lib1   post      AA      1                     1
# 4    lib1  post2      AG     40                     1             ATG1CAA
# 5    lib1  post2      AA     20                     1
# 6    lib2    pre      TA     40                     1     ATG1ATC GGC2GGG
# 7    lib2    pre      TT     30                     1             ATG1ATC
# 8    lib2   post      TT     15                     1             ATG1ATC
# 9    lib2   post      TA      5                     1     ATG1ATC GGC2GGG
#
#   aa_substitutions  n_codon_substitutions  n_aa_substitutions
# 0              M1Q                      1                   1
# 1                                       0                   0
# 2              M1Q                      1                   1
# 3                                       0                   0
# 4              M1Q                      1                   1
# 5                                       0                   0
# 6              M1I                      2                   1
# 7              M1I                      1                   1
# 8              M1I                      1                   1
# 9              M1I                      2                   1

# %% [markdown]
# Now compute escape scores:

# %%
sample_df = pd.DataFrame.from_records([
        ('name1', 'pre', 'post', 0.59),
        ('name2', 'pre', 'post2', 0.2),
        ],
        columns=['name', 'pre_sample', 'post_sample', 'frac_escape'])

variants.escape_scores(sample_df,
                       libraries=variants.libraries,
                       )
# Out:
#     name library pre_sample post_sample barcode     score  score_var  \
# 0  name1    lib1        pre        post      AG  2.740562   1.689190
# 1  name1    lib1        pre        post      AA  0.122887   0.005731
# 2  name1    lib2        pre        post      TA  0.455799   0.009381
# 3  name1    lib2        pre        post      TT  6.643856   4.640857
# 4  name2    lib1        pre       post2      AG  0.323371   0.000916
# 5  name2    lib1        pre       post2      AA  0.319115   0.001611
#
#    score_at_ceil  bind_frac  pre_count  post_count codon_substitutions  \
# 0          False   0.149627         20          30             ATG1CAA
# 1          False   0.918348         10           1
# 2          False   0.729106         40           5     ATG1ATC GGC2GGG
# 3           True   0.010000         30          15             ATG1ATC
# 4          False   0.799200         20          40             ATG1CAA
# 5          False   0.801561         10          20
#
#    n_codon_substitutions aa_substitutions  n_aa_substitutions
# 0                      1              M1Q                   1
# 1                      0                                    0
# 2                      2              M1I                   1
# 3                      1              M1I                   1
# 4                      1              M1Q                   1
# 5                      0                                    0

# %% [markdown]
# With a different floor:

# %%
variants.escape_scores(sample_df,
                       libraries=variants.libraries,
                       floor_B=0.001,
                       )
# Out:
#     name library pre_sample post_sample barcode     score   score_var  \
# 0  name1    lib1        pre        post      AG  2.740562    1.689190
# 1  name1    lib1        pre        post      AA  0.122887    0.005731
# 2  name1    lib2        pre        post      TA  0.455799    0.009381
# 3  name1    lib2        pre        post      TT  9.965784  225.601515
# 4  name2    lib1        pre       post2      AG  0.323371    0.000916
# 5  name2    lib1        pre       post2      AA  0.319115    0.001611
#
#    score_at_ceil  bind_frac  pre_count  post_count codon_substitutions  \
# 0          False   0.149627         20          30             ATG1CAA
# 1          False   0.918348         10           1
# 2          False   0.729106         40           5     ATG1ATC GGC2GGG
# 3           True   0.001000         30          15             ATG1ATC
# 4          False   0.799200         20          40             ATG1CAA
# 5          False   0.801561         10          20
#
#    n_codon_substitutions aa_substitutions  n_aa_substitutions
# 0                      1              M1Q                   1
# 1                      0                                    0
# 2                      2              M1I                   1
# 3                      1              M1I                   1
# 4                      1              M1Q                   1
# 5                      0                                    0

# %% [markdown]
# With a different pseudocount:

# %%
variants.escape_scores(sample_df,
                       libraries=variants.libraries,
                       pseudocount=2,
                       )
# Out:
#     name library pre_sample post_sample barcode     score  score_var  \
# 0  name1    lib1        pre        post      AG  2.587813   1.019757
# 1  name1    lib1        pre        post      AA  0.223114   0.004452
# 2  name1    lib2        pre        post      TA  0.521172   0.006250
# 3  name1    lib2        pre        post      TT  4.896782   8.630904
# 4  name2    lib1        pre       post2      AG  0.327060   0.000722
# 5  name2    lib1        pre       post2      AA  0.312566   0.001084
#
#    score_at_ceil  bind_frac  pre_count  post_count codon_substitutions  \
# 0          False   0.166338         20          30             ATG1CAA
# 1          False   0.856714         10           1
# 2          False   0.696806         40           5     ATG1ATC GGC2GGG
# 3          False   0.033568         30          15             ATG1ATC
# 4          False   0.797159         20          40             ATG1CAA
# 5          False   0.805208         10          20
#
#    n_codon_substitutions aa_substitutions  n_aa_substitutions
# 0                      1              M1Q                   1
# 1                      0                                    0
# 2                      2              M1I                   1
# 3                      1              M1I                   1
# 4                      1              M1Q                   1
# 5                      0                                    0

# %% [markdown]
# By amino-acid substitution:

# %%
variants.escape_scores(sample_df,
                       libraries=variants.libraries,
                       floor_B=0.001,
                       by='aa_substitutions',
                       )
# Out:
#     name library pre_sample post_sample aa_substitutions     score  score_var  \
# 0  name1    lib1        pre        post              M1Q  2.740562   1.689190
# 1  name1    lib1        pre        post                   0.122887   0.005731
# 2  name1    lib2        pre        post              M1I  1.286304   0.000000
# 3  name2    lib1        pre       post2              M1Q  0.323371   0.000916
# 4  name2    lib1        pre       post2                   0.319115   0.001611
#
#    score_at_ceil  bind_frac  pre_count  post_count  n_aa_substitutions
# 0          False   0.149627         20          30                   1
# 1          False   0.918348         10           1                   0
# 2          False   0.410000         70          20                   1
# 3          False   0.799200         20          40                   1
# 4          False   0.801561         10          20                   0

# %% [markdown]
# Include all libraries only:

# %%
variants.escape_scores(sample_df,
                       floor_B=0.001,
                       )
# Out:
#      name        library pre_sample post_sample  barcode     score  \
# 0   name1           lib1        pre        post       AG  2.740562
# 1   name1           lib1        pre        post       AA  0.122887
# 2   name1           lib2        pre        post       TA  0.455799
# 3   name1           lib2        pre        post       TT  9.965784
# 4   name1  all libraries        pre        post  lib1-AG  9.965784
# 5   name1  all libraries        pre        post  lib1-AA  0.255340
# 6   name1  all libraries        pre        post  lib2-TA  0.241611
# 7   name1  all libraries        pre        post  lib2-TT  1.241417
# 8   name2           lib1        pre       post2       AG  0.323371
# 9   name2           lib1        pre       post2       AA  0.319115
# 10  name2  all libraries        pre       post2  lib1-AG       NaN
# 11  name2  all libraries        pre       post2  lib1-AA       NaN
#
#      score_var  score_at_ceil  bind_frac  pre_count  post_count  \
# 0     1.689190          False   0.149627         20          30
# 1     0.005731          False   0.918348         10           1
# 2     0.009381          False   0.729106         40           5
# 3   225.601515           True   0.001000         30          15
# 4     0.000000           True   0.001000         20          30
# 5     0.028379          False   0.837790         10           1
# 6     0.004002          False   0.845800         40           5
# 7     0.010489          False   0.422957         30          15
# 8     0.000916          False   0.799200         20          40
# 9     0.001611          False   0.801561         10          20
# 10         NaN          False        NaN         20          40
# 11         NaN          False        NaN         10          20
#
#    codon_substitutions  n_codon_substitutions aa_substitutions  \
# 0              ATG1CAA                      1              M1Q
# 1                                           0
# 2      ATG1ATC GGC2GGG                      2              M1I
# 3              ATG1ATC                      1              M1I
# 4              ATG1CAA                      1              M1Q
# 5                                           0
# 6      ATG1ATC GGC2GGG                      2              M1I
# 7              ATG1ATC                      1              M1I
# 8              ATG1CAA                      1              M1Q
# 9                                           0
# 10             ATG1CAA                      1              M1Q
# 11                                          0
#
#     n_aa_substitutions
# 0                    1
# 1                    0
# 2                    1
# 3                    1
# 4                    1
# 5                    0
# 6                    1
# 7                    1
# 8                    1
# 9                    0
# 10                   1
# 11                   0

# %% [markdown]
# Raise an error when we hit the floor on binding fraction:

# %%
# NBVAL_RAISES_EXCEPTION

variants.escape_scores(sample_df,
                       handle_small_B='error',
                       )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-e9d7d1818aa0> in <module>
#       2
#       3 variants.escape_scores(sample_df,
# ----> 4                        handle_small_B='error',
#       5                        )
#
# ~/Documents/dms_variants/dms_variants/codonvarianttable.py in escape_scores(self, sample_df, pseudocount, by, libraries, logbase, floor_B, handle_small_B)
#     827             return _df_scores
#     828
# --> 829         df_scores = _compute_escape_scores(pseudocount, pseudocount)
#     830
#     831         # get numerical derivatives
#
# ~/Documents/dms_variants/dms_variants/codonvarianttable.py in _compute_escape_scores(pre_pseudocount, post_pseudocount)
#     814             elif handle_small_B == 'error':
#     815                 if _df_scores['B_v'].min() <= 0:
# --> 816                     raise ValueError('some B_v <= 0; see `handle_small_B`')
#     817                 _df_scores['score_at_ceil'] = False
#     818             else:
#
# ValueError: some B_v <= 0; see `handle_small_B`
